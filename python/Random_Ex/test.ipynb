# %%
import os
path = r'C:\Users\Krips\curseforge\minecraft\Instances\All the Mods 8 - ATM8\mods'
mods = os.listdir(path)
print(mods)
# Out:
# ['absentbydesign-1.19-1.7.0.jar', 'AdditionalEnchantedMiner-1.19.2-19.10.1.jar', 'additionallanterns-1.0.1a-forge-mc1.19.jar', 'additional_lights-1.19-2.1.5.jar', 'AdvancedPeripherals-0.7.22b.jar', 'AdvancementPlaques-1.19.2-1.4.7.jar', 'advgenerators-1.4.0.5-mc1.19.2.jar', 'ad_astra-forge-1.19.2-1.11.9.jar', 'AE2-Things-1.1.0-beta.jar', 'AE2WTLib-12.8.4.jar', 'AEAdditions-1.19.2-4.0.2.jar', 'AEInfinityBooster-1.19.2-1.2.0+11.jar', 'alchemistry-1.19.2-2.2.3.jar', 'alchemylib-1.19.2-1.0.19.jar', 'AllTheCompressed-1.19.2-2.0.0.jar', 'allthemodium-2.1.3-1.19.2-43.1.1.jar', 'alltheores-2.0.2-1.19.2-43.1.3.jar', 'allthetweaks-2.0.4-1.19.2-43.1.3.jar', 'almostunified-forge-1.19.2-0.3.3.jar', 'AngelRing2-1.19.2-2.1.5.jar', 'antighost-1.19.1-forge42.0.1-1.1.2.jar', 'Apotheosis-1.19.2-6.0.1.jar', 'appleskin-forge-mc1.19-2.4.2.jar', 'Applied-Mekanistics-1.3.3.jar', 'appliedcooking-2.0.3.jar', 'appliedenergistics2-forge-12.9.1.jar', 'Aquaculture-1.19.2-2.4.8.jar', 'architectury-6.3.56-forge.jar
# ...
